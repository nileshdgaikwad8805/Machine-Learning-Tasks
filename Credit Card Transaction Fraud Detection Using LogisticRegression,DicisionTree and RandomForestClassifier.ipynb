# %% [markdown]
# Importing Dependencies

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier

# %% [markdown]
# Importing data

# %%
train = pd.read_csv('/content/fraudTrain.csv')
test = pd.read_csv('/content/fraudTest.csv')

# %% [markdown]
# train data

# %%
train.head()
# Out:
#    Unnamed: 0 trans_date_trans_time            cc_num  \
# 0           0   2019-01-01 00:00:18  2703186189652095
# 1           1   2019-01-01 00:00:44      630423337322
# 2           2   2019-01-01 00:00:51    38859492057661
# 3           3   2019-01-01 00:01:16  3534093764340240
# 4           4   2019-01-01 00:03:06   375534208663984
#
#                              merchant       category     amt      first  \
# 0          fraud_Rippin, Kub and Mann       misc_net    4.97   Jennifer
# 1     fraud_Heller, Gutmann and Zieme    grocery_pos  107.23  Stephanie
# 2                fraud_Lind-Buckridge  entertainment  220.11     Edward
# 3  fraud_Kutch, Hermiston and Farrell  gas_transport   45.00     Jeremy
# 4                 fraud_Keeling-Crist       misc_pos   41.96      Tyler
#
#       last gender                        street  ...      lat      long  \
# 0    Banks      F                561 Perry Cove  ...  36.0788  -81.1781
# ...

# %% [markdown]
# test data

# %%
test.head()
# Out:
#    Unnamed: 0 trans_date_trans_time            cc_num  \
# 0           0   2020-06-21 12:14:25  2291163933867244
# 1           1   2020-06-21 12:14:33  3573030041201292
# 2           2   2020-06-21 12:14:53  3598215285024754
# 3           3   2020-06-21 12:15:15  3591919803438423
# 4           4   2020-06-21 12:15:17  3526826139003047
#
#                                merchant        category    amt   first  \
# 0                 fraud_Kirlin and Sons   personal_care   2.86    Jeff
# 1                  fraud_Sporer-Keebler   personal_care  29.84  Joanne
# 2  fraud_Swaniawski, Nitzsche and Welch  health_fitness  41.28  Ashley
# 3                     fraud_Haley Group        misc_pos  60.05   Brian
# 4                 fraud_Johnston-Casper          travel   3.19  Nathan
#
#        last gender                       street  ...      lat      long  \
# 0   Elliott      M            351 Darlene Green  ...  33.9659  -80.9355
# ...

# %% [markdown]
# Short Statistical Summary of train

# %%
train.describe()
# Out:
#          Unnamed: 0        cc_num           amt           zip           lat  \
# count  1.296675e+06  1.296675e+06  1.296675e+06  1.296675e+06  1.296675e+06
# mean   6.483370e+05  4.171920e+17  7.035104e+01  4.880067e+04  3.853762e+01
# std    3.743180e+05  1.308806e+18  1.603160e+02  2.689322e+04  5.075808e+00
# min    0.000000e+00  6.041621e+10  1.000000e+00  1.257000e+03  2.002710e+01
# 25%    3.241685e+05  1.800429e+14  9.650000e+00  2.623700e+04  3.462050e+01
# 50%    6.483370e+05  3.521417e+15  4.752000e+01  4.817400e+04  3.935430e+01
# 75%    9.725055e+05  4.642255e+15  8.314000e+01  7.204200e+04  4.194040e+01
# max    1.296674e+06  4.992346e+18  2.894890e+04  9.978300e+04  6.669330e+01
#
#                long      city_pop     unix_time     merch_lat    merch_long  \
# count  1.296675e+06  1.296675e+06  1.296675e+06  1.296675e+06  1.296675e+06
# mean  -9.022634e+01  8.882444e+04  1.349244e+09  3.853734e+01 -9.022646e+01
# ...

# %% [markdown]
# Short Statistical summary of test

# %%
test.describe()
# Out:
#           Unnamed: 0        cc_num            amt            zip  \
# count  555719.000000  5.557190e+05  555719.000000  555719.000000
# mean   277859.000000  4.178387e+17      69.392810   48842.628015
# std    160422.401459  1.309837e+18     156.745941   26855.283328
# min         0.000000  6.041621e+10       1.000000    1257.000000
# 25%    138929.500000  1.800429e+14       9.630000   26292.000000
# 50%    277859.000000  3.521417e+15      47.290000   48174.000000
# 75%    416788.500000  4.635331e+15      83.010000   72011.000000
# max    555718.000000  4.992346e+18   22768.110000   99921.000000
#
#                  lat           long      city_pop     unix_time  \
# count  555719.000000  555719.000000  5.557190e+05  5.557190e+05
# mean       38.543253     -90.231325  8.822189e+04  1.380679e+09
# std         5.061336      13.721780  3.003909e+05  5.201104e+06
# min        20.027100    -165.672300  2.300000e+01  1.371817e+09
# ...

# %% [markdown]
# checking values for is_fraud in train data

# %%
train['is_fraud'].value_counts()
# Out:
# 0    1289169
# 1       7506
# Name: is_fraud, dtype: int64

# %% [markdown]
# checking values for is_fraud in test data

# %%
test['is_fraud'].value_counts()
# Out:
# 0    553574
# 1      2145
# Name: is_fraud, dtype: int64

# %% [markdown]
# Accessing columns of train_data

# %%
train.columns
# Out:
# Index(['Unnamed: 0', 'trans_date_trans_time', 'cc_num', 'merchant', 'category',
#        'amt', 'first', 'last', 'gender', 'street', 'city', 'state', 'zip',
#        'lat', 'long', 'city_pop', 'job', 'dob', 'trans_num', 'unix_time',
#        'merch_lat', 'merch_long', 'is_fraud'],
#       dtype='object')

# %% [markdown]
# dropping Unnecessary columns from train data

# %%
train = train.drop(columns=['Unnamed: 0','trans_date_trans_time','cc_num','first','last','street','city','state','zip','dob','trans_num'],axis = 1)

# %%
train.head()
# Out:
#                              merchant       category     amt gender      lat  \
# 0          fraud_Rippin, Kub and Mann       misc_net    4.97      F  36.0788
# 1     fraud_Heller, Gutmann and Zieme    grocery_pos  107.23      F  48.8878
# 2                fraud_Lind-Buckridge  entertainment  220.11      M  42.1808
# 3  fraud_Kutch, Hermiston and Farrell  gas_transport   45.00      M  46.2306
# 4                 fraud_Keeling-Crist       misc_pos   41.96      M  38.4207
#
#        long  city_pop                                job   unix_time  \
# 0  -81.1781      3495          Psychologist, counselling  1325376018
# 1 -118.2105       149  Special educational needs teacher  1325376044
# 2 -112.2620      4154        Nature conservation officer  1325376051
# 3 -112.1138      1939                    Patent attorney  1325376076
# 4  -79.4629        99     Dance movement psychotherapist  1325376186
#
#    merch_lat  merch_long  is_fraud
# 0  36.011293  -82.048315         0
# ...

# %% [markdown]
# dropping unnecessary columns for test data

# %%
test = test.drop(columns=['Unnamed: 0','trans_date_trans_time','cc_num','first','last','street','city','state','zip','dob','trans_num'],axis = 1)

# %% [markdown]
# checking test data

# %%
test.head()
# Out:
#                                merchant        category    amt gender  \
# 0                 fraud_Kirlin and Sons   personal_care   2.86      M
# 1                  fraud_Sporer-Keebler   personal_care  29.84      F
# 2  fraud_Swaniawski, Nitzsche and Welch  health_fitness  41.28      F
# 3                     fraud_Haley Group        misc_pos  60.05      M
# 4                 fraud_Johnston-Casper          travel   3.19      M
#
#        lat      long  city_pop                     job   unix_time  merch_lat  \
# 0  33.9659  -80.9355    333497     Mechanical engineer  1371816865  33.986391
# 1  40.3207 -110.4360       302  Sales professional, IT  1371816873  39.450498
# 2  40.6729  -73.5365     34496       Librarian, public  1371816893  40.495810
# 3  28.5697  -80.8191     54767            Set designer  1371816915  28.812398
# 4  44.2529  -85.0170      1126      Furniture designer  1371816917  44.959148
#
#    merch_long  is_fraud
# 0  -81.200714         0
# 1 -109.960431         0
# ...

# %% [markdown]
# creating object of LabelEncoder

# %%
encoder = LabelEncoder()

# %% [markdown]
# transforming categorical data with LabelEncoder

# %%
train['merchant'] = encoder.fit_transform(train['merchant'])
train['category'] = encoder.fit_transform(train['category'])
train['gender'] = encoder.fit_transform(train['gender'])
train['job'] = encoder.fit_transform(train['job'])
test['merchant'] = encoder.fit_transform(test['merchant'])
test['category'] = encoder.fit_transform(test['category'])
test['gender'] = encoder.fit_transform(test['gender'])
test['job'] = encoder.fit_transform(test['job'])

# %% [markdown]
# checking after transformation

# %%
train.head()
# Out:
#    merchant  category     amt  gender      lat      long  city_pop  job  \
# 0       514         8    4.97       0  36.0788  -81.1781      3495  370
# 1       241         4  107.23       0  48.8878 -118.2105       149  428
# 2       390         0  220.11       1  42.1808 -112.2620      4154  307
# 3       360         2   45.00       1  46.2306 -112.1138      1939  328
# 4       297         9   41.96       1  38.4207  -79.4629        99  116
#
#     unix_time  merch_lat  merch_long  is_fraud
# 0  1325376018  36.011293  -82.048315         0
# 1  1325376044  49.159047 -118.186462         0
# 2  1325376051  43.150704 -112.154481         0
# 3  1325376076  47.034331 -112.561071         0
# 4  1325376186  38.674999  -78.632459         0

# %% [markdown]
# dividing data into data and labels

# %%
x_train = train.drop('is_fraud',axis = 1)

# %%
y_train = train['is_fraud']

# %% [markdown]
# replacing values from 0.0 to 0

# %%
y_train.replace(0.0,0)
# Out:
# 0          0
# 1          0
# 2          0
# 3          0
# 4          0
#           ..
# 1296670    0
# 1296671    0
# 1296672    0
# 1296673    0
# 1296674    0
# Name: is_fraud, Length: 1296675, dtype: int64

# %% [markdown]
# checking after replacement

# %%
y_train
# Out:
# 0          0
# 1          0
# 2          0
# 3          0
# 4          0
#           ..
# 1296670    0
# 1296671    0
# 1296672    0
# 1296673    0
# 1296674    0
# Name: is_fraud, Length: 1296675, dtype: int64

# %% [markdown]
# final checking of data

# %%
x_train
# Out:
#          merchant  category     amt  gender      lat      long  city_pop  job  \
# 0             514         8    4.97       0  36.0788  -81.1781      3495  370
# 1             241         4  107.23       0  48.8878 -118.2105       149  428
# 2             390         0  220.11       1  42.1808 -112.2620      4154  307
# 3             360         2   45.00       1  46.2306 -112.1138      1939  328
# 4             297         9   41.96       1  38.4207  -79.4629        99  116
# ...           ...       ...     ...     ...      ...       ...       ...  ...
# 1296670       499         0   15.56       1  37.7175 -112.4777       258  215
# 1296671         2         1   51.70       1  39.2667  -77.5101       100  360
# 1296672       599         1  105.93       1  32.9396 -105.8189       899  308
# 1296673       509         1   74.90       1  43.3526 -102.5411      1126  485
# 1296674       370         1    4.30       1  45.8433 -113.8748       218  467
#
# ...

# %% [markdown]
# Now comes test data

# %%
test.head()
# Out:
#    merchant  category    amt  gender      lat      long  city_pop  job  \
# 0       319        10   2.86       1  33.9659  -80.9355    333497  275
# 1       591        10  29.84       0  40.3207 -110.4360       302  392
# 2       611         5  41.28       0  40.6729  -73.5365     34496  259
# 3       222         9  60.05       1  28.5697  -80.8191     54767  407
# 4       292        13   3.19       1  44.2529  -85.0170      1126  196
#
#     unix_time  merch_lat  merch_long  is_fraud
# 0  1371816865  33.986391  -81.200714         0
# 1  1371816873  39.450498 -109.960431         0
# 2  1371816893  40.495810  -74.196111         0
# 3  1371816915  28.812398  -80.883061         0
# 4  1371816917  44.959148  -85.884734         0

# %% [markdown]
# dividing data and labels in test dataset

# %%
x_test = test.drop('is_fraud',axis = 1)

# %%
y_test = test['is_fraud']

# %% [markdown]
# creating StandardScaler object for standardization of data

# %%
Scaler = StandardScaler()

# %% [markdown]
# standardizarion of data for both the tables

# %%
x_train = Scaler.fit_transform(x_train)

# %%
x_test = Scaler.fit_transform(x_test)

# %% [markdown]
# checking all shapes

# %%
x_train.shape
# Out:
# (1296675, 11)

# %%
y_train.shape
# Out:
# (1296675,)

# %%
x_test.shape
# Out:
# (555719, 11)

# %%
y_test.shape
# Out:
# (555719,)

# %% [markdown]
# Creating LogisticRegression model

# %%
LRmodel = LogisticRegression()

# %% [markdown]
# Fitting data into the model

# %%
LRmodel.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %% [markdown]
# importing accuracy_score for checking accuracy

# %%
from sklearn.metrics import accuracy_score

# %% [markdown]
# checking accuracy for train data

# %%
LRmodel_train_accuracy = accuracy_score(y_train,LRmodel.predict(x_train))
LRmodel_train_accuracy
# Out:
# 0.9936491410723581

# %% [markdown]
# checking accuracy for test data

# %%
LRmodel_test_accuracy = accuracy_score(y_test,LRmodel.predict(x_test))
LRmodel_test_accuracy
# Out:
# 0.9954851282752614

# %% [markdown]
# creating DicisionTreeClassifier model

# %%
DTmodel = DecisionTreeClassifier()

# %% [markdown]
# Fitting data into the model

# %%
DTmodel.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier()

# %% [markdown]
# checking accuracy score for train data

# %%
DTmodel_train_accuracy = accuracy_score(y_train,DTmodel.predict(x_train))
DTmodel_train_accuracy
# Out:
# 1.0

# %% [markdown]
# checking accuracy score for test data

# %%
DTmodel_test_accuracy = accuracy_score(y_test,DTmodel.predict(x_test))
DTmodel_test_accuracy
# Out:
# 0.9961131435131785

# %% [markdown]
# creating RandomForestClassifier object

# %%
RFmodel = RandomForestClassifier(max_depth = 3)

# %% [markdown]
# Fitting data into the model

# %%
RFmodel.fit(x_train,y_train)
# Out:
# RandomForestClassifier(max_depth=3)

# %% [markdown]
# checking accuracy for training data

# %%
RFmodel_train_accuracy = accuracy_score(y_train,RFmodel.predict(x_train))
RFmodel_train_accuracy
# Out:
# 0.9942206026953554

# %% [markdown]
# checking accuracy score for test data

# %%
RFmodel_test_accuracy = accuracy_score(y_test,RFmodel.predict(x_test))
RFmodel_test_accuracy
# Out:
# 0.9961401355721147

# %% [markdown]
# checking accuracy for all the models till used

# %%
print('LogisticRegression model accuracy = ',LRmodel_test_accuracy)
print('DicisionTreeClassifier model accuracy = ',DTmodel_test_accuracy)
print('RandomForestClassifier model accuracy = ',RFmodel_test_accuracy)
# Out:
# LogisticRegression model accuracy =  0.9954851282752614
# DicisionTreeClassifier model accuracy =  0.9961131435131785
# RandomForestClassifier model accuracy =  0.9961401355721147

# %% [markdown]
# Making Prediction code

# %% [markdown]
# for encoding use this function

# %%
merchant = input('Enter Merchant')
merchant = encoder.transform(merchant)
category = input('Enter Category')
category = encoder.transform(merchant)
gender = input('Enter Gender')
gender = encoder.transform(gender)
job = input('Enter Job')
job = encoder.transform(job)

# %% [markdown]
# Move your all values as a array into the standardScaler

# %%
data = tuple(input('input all data by comma seperated'))

# %%
data = Scaler.transform()

# %%
input_data =  (514,8,4.97,0,36.0788,-81.1781,3495,370,1325376018,36.011293,-82.048315)
input_array = np.asarray(input_data)
input_array_reshaped = input_array.reshape(1,-1)
prediction =LRmodel.predict(input_array_reshaped)
if prediction[0] == 0:
  print('Not Fraud')
else:
  print('Fraud')
# Out:
# Not Fraud
